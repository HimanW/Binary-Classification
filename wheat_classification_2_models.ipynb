# %% [markdown]
# # Binary Classification: Wheat Plant State (Ready to Harvest vs Not Ready to Harvest)
#
# This notebook implements a comprehensive binary classification system for aerial wheat imagery using state-of-the-art CNN architectures with transfer learning.
#
# ## Key Features:
# - Advanced data preprocessing and augmentation
# - Multiple CNN backbone comparisons (ResNet, EfficientNet, MobileNet)
# - Comprehensive overfitting mitigation strategies
# - Model checkpointing and evaluation metrics
# - Optimized for 3,800 image dataset (1,900 per class)

# %%
# Install required packages
# !pip install -q imagehash
# !pip install -q efficientnet
# !pip install -q tensorflow-addons
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 11.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 5.1 MB/s eta 0:00:00
# ERROR: Could not find a version that satisfies the requirement tensorflow-addons (from versions: none)
# ERROR: No matching distribution found for tensorflow-addons

# %% [markdown]
# ## 1. Import Libraries and Setup

# %%
import os
import shutil
import hashlib
import imagehash
import numpy as np
import pandas as pd
from PIL import Image
import tensorflow as tf
from pathlib import Path
from tensorflow import keras
from tensorflow.keras import layers, regularizers, mixed_precision
from tensorflow.keras.applications import (
    ResNet50V2, EfficientNetB0, EfficientNetB3, MobileNetV2
)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import (
    EarlyStopping, ReduceLROnPlateau, ModelCheckpoint,
    CSVLogger, LearningRateScheduler
)
from matplotlib import pyplot as plt
from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import (
    confusion_matrix, roc_curve, auc, precision_recall_curve,
    f1_score, classification_report, roc_auc_score
)
from sklearn.utils.class_weight import compute_class_weight
import seaborn as sns
import logging
import warnings
import json
from datetime import datetime

# Configure logging and warnings
logging.basicConfig(level=logging.WARNING)
warnings.filterwarnings('ignore')

# Set plot style
plt.style.use('default')
sns.set_palette("husl")

# %% [markdown]
# ## 2. GPU Setup and Configuration

# %%
def setup_gpu_and_reproducibility():
    """Configure GPU and ensure reproducible results"""
    # GPU Configuration
    gpus = tf.config.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
            print(f"✓ {len(gpus)} GPU(s) available and configured")
        except RuntimeError as e:
            print(f"GPU configuration error: {e}")
    else:
        print("⚠ No GPU available, running on CPU")

    # Reproducibility settings
    SEED = 42
    os.environ['PYTHONHASHSEED'] = str(SEED)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
    np.random.seed(SEED)
    tf.random.set_seed(SEED)
    tf.keras.utils.set_random_seed(SEED)
    tf.config.experimental.enable_op_determinism()

    # Mixed precision for faster training
    mixed_precision.set_global_policy("mixed_float16")
    print("✓ Mixed precision enabled")
    print("✓ Reproducibility configured")

    return SEED

SEED = setup_gpu_and_reproducibility()
# Out:
# ✓ 1 GPU(s) available and configured
# ✓ Mixed precision enabled
# ✓ Reproducibility configured

# %%
# Mount Google Drive (if using Colab)
try:
    from google.colab import drive
    drive.mount('/content/drive')
    print("✓ Google Drive mounted")
except ImportError:
    print("Not running in Colab - skipping Drive mount")
# Out:
# Mounted at /content/drive
# ✓ Google Drive mounted

# %% [markdown]
# ## 3. Configuration and Constants

# %%
# Dataset Configuration
CONFIG = {
    # Paths
    'source_dir': Path('/content/drive/MyDrive/training-setX'),
    'output_base_dir': Path('/content/drive/MyDrive/clean_dataset'),
    'models_dir': Path('/content/drive/MyDrive/wheat_models'),
    'results_dir': Path('/content/drive/MyDrive/wheat_results'),

    # Data splits
    'train_ratio': 0.7,
    'val_ratio': 0.2,
    'test_ratio': 0.1,

    # Image processing
    'img_size': (224, 224),  # Standard size for pre-trained models
    'batch_size': 32,        # Optimized for 3800 images
    'hash_size': 8,
    'min_std_threshold': 10, # Filter out low-variance images

    # Training parameters
    'epochs': 35,
    'initial_lr': 1e-4,
    'patience': 15,
    'min_lr': 1e-7,

    # Model architectures to compare
    'models_to_test': ['EfficientNetB0', 'ResNet50V2', 'MobileNetV2'],

    # Regularization
    'dropout_rate': 0.3,
    'l2_reg': 1e-4,

    # Random seed
    'random_state': SEED
}

# Create directories
for dir_path in [CONFIG['models_dir'], CONFIG['results_dir']]:
    dir_path.mkdir(parents=True, exist_ok=True)

print("Configuration:")
for key, value in CONFIG.items():
    print(f"  {key}: {value}")
# Out:
# Configuration:
#   source_dir: /content/drive/MyDrive/training-setX
#   output_base_dir: /content/drive/MyDrive/clean_dataset
#   models_dir: /content/drive/MyDrive/wheat_models
#   results_dir: /content/drive/MyDrive/wheat_results
#   train_ratio: 0.7
#   val_ratio: 0.2
#   test_ratio: 0.1
#   img_size: (224, 224)
#   batch_size: 32
#   hash_size: 8
#   min_std_threshold: 10
#   epochs: 35
#   initial_lr: 0.0001
#   patience: 15
#   min_lr: 1e-07
#   models_to_test: ['EfficientNetB0', 'ResNet50V2', 'MobileNetV2']
#   dropout_rate: 0.3
#   l2_reg: 0.0001
#   random_state: 42

# %% [markdown]
# ## 4. Advanced Data Processing and Cleaning

# %%
def get_image_features(image_path, hash_size=8, min_std=10):
    """Extract comprehensive image features for duplicate detection and quality assessment"""
    try:
        # File hash for exact duplicates
        with open(image_path, 'rb') as f:
            file_hash = hashlib.md5(f.read()).hexdigest()

        # Load and analyze image
        img = Image.open(image_path).convert('RGB')
        img_array = np.array(img, dtype=np.float32)

        # Quality checks
        std = img_array.std()
        if std < min_std:
            return None  # Skip low-variance images

        # Perceptual hash for near-duplicates
        perceptual_hash = imagehash.phash(img, hash_size=hash_size)

        # Additional features
        mean_brightness = img_array.mean()
        contrast = img_array.max() - img_array.min()

        return {
            'file_hash': file_hash,
            'perceptual_hash': str(perceptual_hash),
            'std': std,
            'mean_brightness': mean_brightness,
            'contrast': contrast,
            'shape': img.size,
            'path': str(image_path)
        }
    except Exception as e:
        logging.warning(f"Error processing {image_path}: {e}")
        return None

def remove_duplicates(features_list, hamming_threshold=5):
    """Remove exact and near-duplicate images using hash comparison"""
    unique_features = []
    seen_hashes = set()
    perceptual_hashes = []

    print(f"Processing {len(features_list)} images for duplicate removal...")

    for features in features_list:
        # Remove exact duplicates
        if features['file_hash'] in seen_hashes:
            continue

        # Check for near-duplicates
        current_hash = imagehash.hex_to_hash(features['perceptual_hash'])
        is_duplicate = False

        for existing_hash in perceptual_hashes:
            if abs(current_hash - existing_hash) <= hamming_threshold:
                is_duplicate = True
                break

        if not is_duplicate:
            unique_features.append(features)
            seen_hashes.add(features['file_hash'])
            perceptual_hashes.append(current_hash)

    removed = len(features_list) - len(unique_features)
    print(f"✓ Removed {removed} duplicate images")
    return unique_features

def analyze_dataset_distribution(features_list):
    """Analyze and visualize dataset characteristics"""
    df = pd.DataFrame(features_list)

    print("\nDataset Analysis:")
    print(f"Total images: {len(df)}")
    print(f"Classes: {df['class'].value_counts().to_dict()}")
    print(f"Average image std: {df['std'].mean():.2f}")
    print(f"Average brightness: {df['mean_brightness'].mean():.2f}")
    print(f"Average contrast: {df['contrast'].mean():.2f}")

    # Visualization
    fig, axes = plt.subplots(2, 2, figsize=(12, 8))
    fig.suptitle('Dataset Quality Analysis', fontsize=16)

    # Class distribution
    df['class'].value_counts().plot(kind='bar', ax=axes[0,0], color=['green', 'orange'])
    axes[0,0].set_title('Class Distribution')
    axes[0,0].set_ylabel('Number of Images')

    # Image quality metrics
    df['std'].hist(bins=30, ax=axes[0,1], alpha=0.7)
    axes[0,1].set_title('Image Standard Deviation')
    axes[0,1].set_xlabel('Standard Deviation')

    df['mean_brightness'].hist(bins=30, ax=axes[1,0], alpha=0.7)
    axes[1,0].set_title('Average Brightness')
    axes[1,0].set_xlabel('Brightness')

    df['contrast'].hist(bins=30, ax=axes[1,1], alpha=0.7)
    axes[1,1].set_title('Image Contrast')
    axes[1,1].set_xlabel('Contrast')

    plt.tight_layout()
    plt.show()

    return df

# %%
# Process and analyze dataset
print("Starting dataset processing...")

# Collect image features
all_features = []
processed_count = 0

for class_dir in CONFIG['source_dir'].iterdir():
    if class_dir.is_dir():
        print(f"Processing class: {class_dir.name}")
        class_count = 0

        for img_file in class_dir.iterdir():
            if img_file.suffix.lower() in ['.png', '.jpg', '.jpeg']:
                features = get_image_features(
                    img_file,
                    CONFIG['hash_size'],
                    CONFIG['min_std_threshold']
                )
                if features:
                    features['class'] = class_dir.name
                    features['filename'] = img_file.name
                    all_features.append(features)
                    class_count += 1

                processed_count += 1
                if processed_count % 500 == 0:
                    print(f"  Processed {processed_count} images...")

        print(f"  ✓ {class_count} valid images found in {class_dir.name}")

print(f"\n✓ Initial processing complete: {len(all_features)} valid images")
# Out:
# Starting dataset processing...
# Processing class: Ready
#   Processed 500 images...
#   Processed 1000 images...
#   Processed 1500 images...
#   ✓ 1900 valid images found in Ready
# Processing class: not-Ready
#   Processed 2000 images...
#   Processed 2500 images...
#   Processed 3000 images...
#   Processed 3500 images...
#   ✓ 1900 valid images found in not-Ready
#
# ✓ Initial processing complete: 3800 valid images

# %%
# Remove duplicates and analyze dataset
clean_features = remove_duplicates(all_features)
dataset_df = analyze_dataset_distribution(clean_features)

# Save cleaned dataset info
dataset_info_path = CONFIG['results_dir'] / 'dataset_info.json'
with open(dataset_info_path, 'w') as f:
    dataset_info = {
        'total_images': len(clean_features),
        'class_distribution': dataset_df['class'].value_counts().to_dict(),
        'avg_std': float(dataset_df['std'].mean()),
        'avg_brightness': float(dataset_df['mean_brightness'].mean()),
        'avg_contrast': float(dataset_df['contrast'].mean()),
        'processing_timestamp': datetime.now().isoformat()
    }
    json.dump(dataset_info, f, indent=2)

print(f"✓ Dataset information saved to {dataset_info_path}")
# Out:
# Processing 3800 images for duplicate removal...
# ✓ Removed 38 duplicate images
#
# Dataset Analysis:
# Total images: 3762
# Classes: {'not-Ready': 1899, 'Ready': 1863}
# Average image std: 48.39
# Average brightness: 78.20
# Average contrast: 251.42
# ✓ Dataset information saved to /content/drive/MyDrive/wheat_results/dataset_info.json

# %% [markdown]
# ## 5. Intelligent Data Splitting

# %%
def create_stratified_splits(dataset_df, config):
    """Create stratified train/val/test splits with group-based splitting to avoid data leakage"""

    # Create groups based on image similarity (using perceptual hash)
    # This helps prevent similar images from appearing in different splits
    dataset_df['group'] = dataset_df.groupby('perceptual_hash').ngroup()

    # First split: separate test set
    splitter1 = GroupShuffleSplit(
        n_splits=1,
        test_size=config['test_ratio'],
        random_state=config['random_state']
    )

    train_val_idx, test_idx = next(splitter1.split(
        dataset_df, dataset_df['class'], dataset_df['group']
    ))

    # Second split: separate train and validation
    train_val_df = dataset_df.iloc[train_val_idx].copy()
    val_size = config['val_ratio'] / (config['train_ratio'] + config['val_ratio'])

    splitter2 = GroupShuffleSplit(
        n_splits=1,
        test_size=val_size,
        random_state=config['random_state']
    )

    train_idx, val_idx = next(splitter2.split(
        train_val_df, train_val_df['class'], train_val_df['group']
    ))

    # Create final splits
    splits = {
        'train': train_val_df.iloc[train_idx].copy(),
        'val': train_val_df.iloc[val_idx].copy(),
        'test': dataset_df.iloc[test_idx].copy()
    }

    # Print split information
    print("\nDataset Splits:")
    for split_name, split_df in splits.items():
        class_counts = split_df['class'].value_counts()
        print(f"{split_name.upper()}:")
        print(f"  Total: {len(split_df)}")
        for class_name, count in class_counts.items():
            percentage = (count / len(split_df)) * 100
            print(f"  {class_name}: {count} ({percentage:.1f}%)")

    return splits

# Create splits
data_splits = create_stratified_splits(dataset_df, CONFIG)

# Save split information
for split_name, split_df in data_splits.items():
    split_path = CONFIG['results_dir'] / f'{split_name}_split.csv'
    split_df.to_csv(split_path, index=False)
    print(f"✓ {split_name} split saved to {split_path}")
# Out:
# Dataset Splits:
# TRAIN:
#   Total: 2632
#   not-Ready: 1352 (51.4%)
#   Ready: 1280 (48.6%)
# VAL:
#   Total: 753
#   Ready: 397 (52.7%)
#   not-Ready: 356 (47.3%)
# TEST:
#   Total: 377
#   not-Ready: 191 (50.7%)
#   Ready: 186 (49.3%)
# ✓ train split saved to /content/drive/MyDrive/wheat_results/train_split.csv
# ✓ val split saved to /content/drive/MyDrive/wheat_results/val_split.csv
# ✓ test split saved to /content/drive/MyDrive/wheat_results/test_split.csv

# %% [markdown]
# ## 6. Advanced Data Pipeline with Augmentation

# %%
def create_data_generators(data_splits, config):
    """Create optimized data generators with agriculture-specific augmentations"""

    # Training augmentation - realistic for aerial crop imagery
    train_datagen = keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255,
        rotation_range=15,          # Small rotations (drone angle variations)
        width_shift_range=0.1,      # Slight position shifts
        height_shift_range=0.1,
        shear_range=0.1,           # Perspective variations
        zoom_range=0.15,           # Altitude variations
        horizontal_flip=True,       # Mirror images
        vertical_flip=True,         # 180° rotations
        brightness_range=[0.8, 1.2], # Lighting conditions
        fill_mode='reflect',
        channel_shift_range=20,     # Color variations
    )

    # Validation/Test - only rescaling
    val_test_datagen = keras.preprocessing.image.ImageDataGenerator(
        rescale=1./255
    )

    def create_temp_directory(split_df, split_name):
        """Create temporary directory structure for ImageDataGenerator"""
        temp_dir = CONFIG['output_base_dir'] / f'temp_{split_name}'
        temp_dir.mkdir(parents=True, exist_ok=True)

        # Create class subdirectories
        for class_name in split_df['class'].unique():
            class_dir = temp_dir / class_name
            class_dir.mkdir(exist_ok=True)

            # Copy images to temporary structure
            class_images = split_df[split_df['class'] == class_name]
            for _, row in class_images.iterrows():
                src_path = Path(row['path'])
                dst_path = class_dir / row['filename']
                if not dst_path.exists() and src_path.exists():
                    shutil.copy2(src_path, dst_path)

        return temp_dir

    # Create temporary directories
    temp_dirs = {}
    generators = {}

    for split_name, split_df in data_splits.items():
        print(f"Setting up {split_name} generator...")
        temp_dirs[split_name] = create_temp_directory(split_df, split_name)

        # Choose appropriate data generator
        datagen = train_datagen if split_name == 'train' else val_test_datagen

        generators[split_name] = datagen.flow_from_directory(
            temp_dirs[split_name],
            target_size=config['img_size'],
            batch_size=config['batch_size'],
            class_mode='binary',
            shuffle=(split_name == 'train'),
            seed=config['random_state']
        )

    return generators, temp_dirs

# Create data generators
print("Creating data generators...")
data_generators, temp_directories = create_data_generators(data_splits, CONFIG)

# Display generator information
for name, gen in data_generators.items():
    print(f"\n{name.upper()} generator:")
    print(f"  Samples: {gen.samples}")
    print(f"  Classes: {gen.class_indices}")
    print(f"  Steps per epoch: {len(gen)}")

print("\n✓ Data generators created successfully")
# Out:
# Creating data generators...
# Setting up train generator...
# Found 2632 images belonging to 2 classes.
# Setting up val generator...
# Found 753 images belonging to 2 classes.
# Setting up test generator...
# Found 377 images belonging to 2 classes.
#
# TRAIN generator:
#   Samples: 2632
#   Classes: {'Ready': 0, 'not-Ready': 1}
#   Steps per epoch: 83
#
# VAL generator:
#   Samples: 753
#   Classes: {'Ready': 0, 'not-Ready': 1}
#   Steps per epoch: 24
#
# TEST generator:
#   Samples: 377
#   Classes: {'Ready': 0, 'not-Ready': 1}
#   Steps per epoch: 12
#
# ✓ Data generators created successfully

# %% [markdown]
# ## 7. Advanced Model Architectures with Transfer Learning

# %%
def create_model(backbone_name, config, input_shape=(224, 224, 3)):
    """Create optimized model with specified backbone for agricultural imagery"""

    # Define backbone architectures
    backbones = {
        'EfficientNetB0': lambda: EfficientNetB0(
            weights='imagenet',
            include_top=False,
            input_shape=input_shape
        ),
        # 'ResNet50V2': lambda: ResNet50V2(
        #     weights='imagenet',
        #     include_top=False,
        #     input_shape=input_shape
        # ),
        'MobileNetV2': lambda: MobileNetV2(
            weights='imagenet',
            include_top=False,
            input_shape=input_shape,
            alpha=1.0
        )
        # 'EfficientNetB3': lambda: EfficientNetB3(
        #     weights='imagenet',
        #     include_top=False,
        #     input_shape=input_shape
        # )
    }

    if backbone_name not in backbones:
        raise ValueError(f"Backbone {backbone_name} not supported. Choose from: {list(backbones.keys())}")

    # Create base model
    base_model = backbones[backbone_name]()
    base_model.trainable = False  # Start with frozen backbone

    # Add custom classification head
    inputs = keras.Input(shape=input_shape)

    # Preprocessing (normalization handled by ImageDataGenerator)
    x = inputs

    # Base model
    x = base_model(x, training=False)

    # Global pooling
    x = layers.GlobalAveragePooling2D()(x)

    # Regularization and classification layers
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(config['dropout_rate'])(x)

    # Dense layers with regularization
    x = layers.Dense(
        512,
        activation='relu',
        kernel_regularizer=regularizers.l2(config['l2_reg']),
        name='feature_dense'
    )(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(config['dropout_rate'])(x)

    x = layers.Dense(
        128,
        activation='relu',
        kernel_regularizer=regularizers.l2(config['l2_reg']),
        name='classification_dense'
    )(x)
    x = layers.Dropout(config['dropout_rate'] * 0.5)(x)

    # Output layer (binary classification)
    outputs = layers.Dense(1, activation='sigmoid', name='predictions')(x)

    model = keras.Model(inputs, outputs, name=f'{backbone_name}_wheat_classifier')

    return model, base_model

def compile_model(model, config):
    """Compile model with optimized settings for binary classification"""

    # Use Adam optimizer with learning rate scheduling
    optimizer = Adam(learning_rate=config['initial_lr'])

    # Loss function for binary classification
    loss = 'binary_crossentropy'

    # Metrics
    metrics = [
        'accuracy',
        keras.metrics.Precision(name='precision'),
        keras.metrics.Recall(name='recall'),
        keras.metrics.AUC(name='auc')
    ]

    model.compile(
        optimizer=optimizer,
        loss=loss,
        metrics=metrics
    )

    return model

def get_callbacks(model_name, config):
    """Create comprehensive callback suite for training"""

    model_dir = config['models_dir'] / model_name
    model_dir.mkdir(exist_ok=True)

    callbacks = [
        # Model checkpointing - save best model
        ModelCheckpoint(
            filepath=str(model_dir / 'best_model.h5'),
            monitor='val_auc',
            mode='max',
            save_best_only=True,
            save_weights_only=False,
            verbose=1
        ),

        # Early stopping to prevent overfitting
        EarlyStopping(
            monitor='val_auc',
            mode='max',
            patience=config['patience'],
            restore_best_weights=True,
            verbose=1
        ),

        # Learning rate reduction
        ReduceLROnPlateau(
            monitor='val_loss',
            mode='min',
            factor=0.2,
            patience=config['patience'] // 2,
            min_lr=config['min_lr'],
            verbose=1
        ),

        # Training log
        CSVLogger(
            filename=str(model_dir / 'training_log.csv'),
            append=False
        )
    ]

    return callbacks

# Test model creation
print("Testing model architectures...")
for backbone in CONFIG['models_to_test']:
    try:
        model, base_model = create_model(backbone, CONFIG)
        model = compile_model(model, CONFIG)
        print(f"✓ {backbone}: {model.count_params():,} parameters")
        print(f"  - Trainable: {sum([tf.keras.backend.count_params(w) for w in model.trainable_weights]):,}")
        print(f"  - Non-trainable: {sum([tf.keras.backend.count_params(w) for w in model.non_trainable_weights]):,}")
        del model, base_model  # Free memory
    except Exception as e:
        print(f"✗ {backbone}: Error - {e}")

print("\n✓ All model architectures tested successfully")
# Out:
# Testing model architectures...
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# ✓ EfficientNetB0: 4,778,404 parameters
#   - Trainable: 725,249
#   - Non-trainable: 4,053,155.0
# ✗ ResNet50V2: Error - Backbone ResNet50V2 not supported. Choose from: ['EfficientNetB0', 'MobileNetV2']
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# ✓ MobileNetV2: 2,986,817 parameters
#   - Trainable: 725,249
#   - Non-trainable: 2,261,568
#
# ✓ All model architectures tested successfully

# %% [markdown]
# ## 8. Model Training with Fine-tuning Strategy

# %%
def calculate_class_weights(generator):
    """Calculate class weights to handle class imbalance"""
    # Get all labels from generator
    labels = []
    for i in range(len(generator)):
        _, batch_labels = generator[i]
        labels.extend(batch_labels.flatten())

    labels = np.array(labels)

    # Calculate class weights
    class_weights = compute_class_weight(
        'balanced',
        classes=np.unique(labels),
        y=labels
    )

    class_weight_dict = {i: weight for i, weight in enumerate(class_weights)}

    print(f"Class weights calculated: {class_weight_dict}")
    return class_weight_dict

def train_model_with_fine_tuning(model_name, config, data_generators, epochs_phase1=25):
    """Train model with two-phase fine-tuning strategy"""

    print(f"\n{'='*50}")
    print(f"Training {model_name}")
    print(f"{'='*50}")

    # Create model
    model, base_model = create_model(model_name, config)
    model = compile_model(model, config)

    # Calculate class weights
    class_weights = calculate_class_weights(data_generators['train'])

    # Get callbacks
    callbacks = get_callbacks(model_name, config)

    # PHASE 1: Train with frozen backbone
    print(f"\nPHASE 1: Training with frozen {model_name} backbone...")
    print(f"Epochs: {epochs_phase1}")
    print(f"Learning rate: {config['initial_lr']}")

    history_phase1 = model.fit(
        data_generators['train'],
        epochs=epochs_phase1,
        validation_data=data_generators['val'],
        class_weight=class_weights,
        callbacks=callbacks,
        verbose=1
    )

    # PHASE 2: Fine-tune with unfrozen backbone
    print(f"\nPHASE 2: Fine-tuning with unfrozen backbone...")

    # Unfreeze the base model for fine-tuning
    base_model.trainable = True

    # Use lower learning rate for fine-tuning
    fine_tune_lr = config['initial_lr'] / 10

    # Recompile with lower learning rate
    model.compile(
        optimizer=Adam(learning_rate=fine_tune_lr),
        loss='binary_crossentropy',
        metrics=[
            'accuracy',
            keras.metrics.Precision(name='precision'),
            keras.metrics.Recall(name='recall'),
            keras.metrics.AUC(name='auc')
        ]
    )

    print(f"Fine-tuning learning rate: {fine_tune_lr}")

    # Update callbacks for phase 2
    model_dir = config['models_dir'] / model_name
    callbacks_phase2 = [
        ModelCheckpoint(
            filepath=str(model_dir / 'best_model_finetuned.h5'),
            monitor='val_auc',
            mode='max',
            save_best_only=True,
            save_weights_only=False,
            verbose=1
        ),
        EarlyStopping(
            monitor='val_auc',
            mode='max',
            patience=config['patience'],
            restore_best_weights=True,
            verbose=1
        ),
        ReduceLROnPlateau(
            monitor='val_loss',
            mode='min',
            factor=0.5,
            patience=config['patience'] // 3,
            min_lr=config['min_lr'],
            verbose=1
        ),
        CSVLogger(
            filename=str(model_dir / 'training_log_phase2.csv'),
            append=False
        )
    ]

    # Continue training with fine-tuning
    remaining_epochs = config['epochs'] - epochs_phase1

    history_phase2 = model.fit(
        data_generators['train'],
        epochs=remaining_epochs,
        validation_data=data_generators['val'],
        class_weight=class_weights,
        callbacks=callbacks_phase2,
        verbose=1
    )

    # Combine histories
    combined_history = {}
    for key in history_phase1.history.keys():
        combined_history[key] = history_phase1.history[key] + history_phase2.history[key]

    # Load best model
    best_model_path = model_dir / 'best_model_finetuned.h5'
    if best_model_path.exists():
        model = keras.models.load_model(str(best_model_path))
        print(f"✓ Best model loaded from {best_model_path}")

    return model, combined_history

# Start training all models
trained_models = {}
training_histories = {}

for model_name in CONFIG['models_to_test']:
    try:
        model, history = train_model_with_fine_tuning(
            model_name, CONFIG, data_generators
        )
        trained_models[model_name] = model
        training_histories[model_name] = history

        print(f"✓ {model_name} training completed successfully")

        # Clear GPU memory
        tf.keras.backend.clear_session()

    except Exception as e:
        print(f"✗ {model_name} training failed: {e}")
        continue

print(f"\n✓ Training completed for {len(trained_models)} models")
# Out:
# ==================================================
# Training EfficientNetB0
# ==================================================
# Class weights calculated: {0: np.float64(1.028125), 1: np.float64(0.9733727810650887)}
#
# PHASE 1: Training with frozen EfficientNetB0 backbone...
# Epochs: 25
# Learning rate: 0.0001
# Epoch 1/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5240 - auc: 0.5246 - loss: 0.9420 - precision: 0.5258 - recall: 0.5923
# Epoch 1: val_auc improved from -inf to 0.50000, saving model to /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 208s 2s/step - accuracy: 0.5238 - auc: 0.5245 - loss: 0.9420 - precision: 0.5258 - recall: 0.5917 - val_accuracy: 0.5272 - val_auc: 0.5000 - val_loss: 0.7858 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 2/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4907 - auc: 0.4797 - loss: 0.9698 - precision: 0.4975 - recall: 0.4877
# Epoch 2: val_auc did not improve from 0.50000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 154s 2s/step - accuracy: 0.4909 - auc: 0.4799 - loss: 0.9695 - precision: 0.4977 - recall: 0.4880 - val_accuracy: 0.5272 - val_auc: 0.4702 - val_loss: 0.8022 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 3/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5279 - auc: 0.5345 - loss: 0.9049 - precision: 0.5353 - recall: 0.5191
# Epoch 3: val_auc improved from 0.50000 to 0.66001, saving model to /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 148s 2s/step - accuracy: 0.5278 - auc: 0.5344 - loss: 0.9049 - precision: 0.5353 - recall: 0.5191 - val_accuracy: 0.5272 - val_auc: 0.6600 - val_loss: 0.7981 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 4/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5052 - auc: 0.5206 - loss: 0.9024 - precision: 0.5224 - recall: 0.5050
# Epoch 4: val_auc improved from 0.66001 to 0.76960, saving model to /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.5053 - auc: 0.5205 - loss: 0.9024 - precision: 0.5225 - recall: 0.5051 - val_accuracy: 0.5272 - val_auc: 0.7696 - val_loss: 0.8034 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 5/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5300 - auc: 0.5355 - loss: 0.8848 - precision: 0.5302 - recall: 0.5296
# Epoch 5: val_auc did not improve from 0.76960
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.5300 - auc: 0.5355 - loss: 0.8847 - precision: 0.5304 - recall: 0.5297 - val_accuracy: 0.5272 - val_auc: 0.6831 - val_loss: 0.8008 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 6/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5243 - auc: 0.5228 - loss: 0.8819 - precision: 0.5343 - recall: 0.5326
# Epoch 6: val_auc improved from 0.76960 to 0.85825, saving model to /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 153s 2s/step - accuracy: 0.5243 - auc: 0.5229 - loss: 0.8819 - precision: 0.5343 - recall: 0.5326 - val_accuracy: 0.5272 - val_auc: 0.8582 - val_loss: 0.8237 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 7/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5351 - auc: 0.5411 - loss: 0.8612 - precision: 0.5293 - recall: 0.5398
# Epoch 7: val_auc did not improve from 0.85825
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.5351 - auc: 0.5411 - loss: 0.8613 - precision: 0.5296 - recall: 0.5397 - val_accuracy: 0.5272 - val_auc: 0.7907 - val_loss: 0.7987 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 8/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5188 - auc: 0.5410 - loss: 0.8542 - precision: 0.5258 - recall: 0.5323
# Epoch 8: val_auc did not improve from 0.85825
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.5190 - auc: 0.5411 - loss: 0.8541 - precision: 0.5260 - recall: 0.5323 - val_accuracy: 0.5272 - val_auc: 0.8328 - val_loss: 0.7913 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-04
# Epoch 9/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5233 - auc: 0.5365 - loss: 0.8507 - precision: 0.5527 - recall: 0.5606
# Epoch 9: val_auc did not improve from 0.85825
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.5232 - auc: 0.5364 - loss: 0.8507 - precision: 0.5524 - recall: 0.5604 - val_accuracy: 0.5272 - val_auc: 0.8569 - val_loss: 0.7918 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 10/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5284 - auc: 0.5315 - loss: 0.8593 - precision: 0.5412 - recall: 0.5180
# Epoch 10: val_auc did not improve from 0.85825
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 211s 2s/step - accuracy: 0.5285 - auc: 0.5316 - loss: 0.8592 - precision: 0.5414 - recall: 0.5182 - val_accuracy: 0.5272 - val_auc: 0.8549 - val_loss: 0.7897 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 11/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5247 - auc: 0.5277 - loss: 0.8604 - precision: 0.5426 - recall: 0.5047
# Epoch 11: val_auc improved from 0.85825 to 0.86635, saving model to /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.5247 - auc: 0.5277 - loss: 0.8604 - precision: 0.5426 - recall: 0.5048 - val_accuracy: 0.5272 - val_auc: 0.8664 - val_loss: 0.7874 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 12/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5217 - auc: 0.5273 - loss: 0.8581 - precision: 0.5119 - recall: 0.5014
# Epoch 12: val_auc improved from 0.86635 to 0.88120, saving model to /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 215s 2s/step - accuracy: 0.5219 - auc: 0.5274 - loss: 0.8579 - precision: 0.5124 - recall: 0.5017 - val_accuracy: 0.5272 - val_auc: 0.8812 - val_loss: 0.7857 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 13/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5318 - auc: 0.5382 - loss: 0.8411 - precision: 0.5509 - recall: 0.5399
# Epoch 13: val_auc did not improve from 0.88120
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.5318 - auc: 0.5383 - loss: 0.8412 - precision: 0.5509 - recall: 0.5399 - val_accuracy: 0.5272 - val_auc: 0.8536 - val_loss: 0.7832 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 14/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5391 - auc: 0.5709 - loss: 0.8139 - precision: 0.5561 - recall: 0.5180
# Epoch 14: val_auc did not improve from 0.88120
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.5392 - auc: 0.5707 - loss: 0.8140 - precision: 0.5562 - recall: 0.5182 - val_accuracy: 0.5272 - val_auc: 0.8599 - val_loss: 0.7847 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 15/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5428 - auc: 0.5652 - loss: 0.8267 - precision: 0.5655 - recall: 0.5398
# Epoch 15: val_auc did not improve from 0.88120
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 145s 2s/step - accuracy: 0.5429 - auc: 0.5653 - loss: 0.8266 - precision: 0.5656 - recall: 0.5399 - val_accuracy: 0.5272 - val_auc: 0.8549 - val_loss: 0.7887 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 16/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5413 - auc: 0.5553 - loss: 0.8294 - precision: 0.5538 - recall: 0.5428
# Epoch 16: val_auc did not improve from 0.88120
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 144s 2s/step - accuracy: 0.5411 - auc: 0.5552 - loss: 0.8295 - precision: 0.5536 - recall: 0.5425 - val_accuracy: 0.5272 - val_auc: 0.8742 - val_loss: 0.7958 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 17/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5288 - auc: 0.5465 - loss: 0.8398 - precision: 0.5527 - recall: 0.5180
# Epoch 17: val_auc did not improve from 0.88120
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 204s 2s/step - accuracy: 0.5290 - auc: 0.5466 - loss: 0.8398 - precision: 0.5528 - recall: 0.5184 - val_accuracy: 0.5272 - val_auc: 0.8664 - val_loss: 0.7932 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 18/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5458 - auc: 0.5712 - loss: 0.8130 - precision: 0.5486 - recall: 0.5224
# Epoch 18: val_auc did not improve from 0.88120
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.5458 - auc: 0.5711 - loss: 0.8131 - precision: 0.5487 - recall: 0.5226 - val_accuracy: 0.5272 - val_auc: 0.8719 - val_loss: 0.7923 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 19/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5330 - auc: 0.5450 - loss: 0.8340 - precision: 0.5490 - recall: 0.5236
# Epoch 19: val_auc improved from 0.88120 to 0.88695, saving model to /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 217s 2s/step - accuracy: 0.5331 - auc: 0.5451 - loss: 0.8340 - precision: 0.5490 - recall: 0.5238 - val_accuracy: 0.5272 - val_auc: 0.8870 - val_loss: 0.7916 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 20/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5345 - auc: 0.5425 - loss: 0.8434 - precision: 0.5669 - recall: 0.5286
# Epoch 20: val_auc did not improve from 0.88695
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.5345 - auc: 0.5426 - loss: 0.8433 - precision: 0.5667 - recall: 0.5285 - val_accuracy: 0.5272 - val_auc: 0.8855 - val_loss: 0.7894 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 2.0000e-05
# Epoch 21/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5400 - auc: 0.5514 - loss: 0.8369 - precision: 0.5611 - recall: 0.5472
# Epoch 21: val_auc did not improve from 0.88695
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.5400 - auc: 0.5514 - loss: 0.8368 - precision: 0.5610 - recall: 0.5472 - val_accuracy: 0.5272 - val_auc: 0.8785 - val_loss: 0.7886 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 4.0000e-06
# Epoch 22/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5353 - auc: 0.5450 - loss: 0.8343 - precision: 0.5584 - recall: 0.5398
# Epoch 22: val_auc improved from 0.88695 to 0.88915, saving model to /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 160s 2s/step - accuracy: 0.5352 - auc: 0.5450 - loss: 0.8343 - precision: 0.5582 - recall: 0.5398 - val_accuracy: 0.5272 - val_auc: 0.8892 - val_loss: 0.7892 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 4.0000e-06
# Epoch 23/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5289 - auc: 0.5421 - loss: 0.8368 - precision: 0.5503 - recall: 0.5375
# Epoch 23: val_auc did not improve from 0.88915
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 143s 2s/step - accuracy: 0.5291 - auc: 0.5422 - loss: 0.8367 - precision: 0.5503 - recall: 0.5377 - val_accuracy: 0.5272 - val_auc: 0.8811 - val_loss: 0.7914 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 4.0000e-06
# Epoch 24/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5447 - auc: 0.5599 - loss: 0.8294 - precision: 0.5674 - recall: 0.5176
# Epoch 24: val_auc did not improve from 0.88915
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 216s 2s/step - accuracy: 0.5447 - auc: 0.5598 - loss: 0.8295 - precision: 0.5673 - recall: 0.5177 - val_accuracy: 0.5272 - val_auc: 0.8850 - val_loss: 0.7897 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 4.0000e-06
# Epoch 25/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5273 - auc: 0.5327 - loss: 0.8455 - precision: 0.5348 - recall: 0.5357
# Epoch 25: val_auc did not improve from 0.88915
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 157s 2s/step - accuracy: 0.5274 - auc: 0.5327 - loss: 0.8454 - precision: 0.5349 - recall: 0.5357 - val_accuracy: 0.5272 - val_auc: 0.8813 - val_loss: 0.7915 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 4.0000e-06
# Restoring model weights from the end of the best epoch: 22.
#
# PHASE 2: Fine-tuning with unfrozen backbone...
# Fine-tuning learning rate: 1e-05
# Epoch 1/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.5396 - auc: 0.5570 - loss: 0.8845 - precision: 0.5439 - recall: 0.6475
# Epoch 1: val_auc improved from -inf to 0.88918, saving model to /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model_finetuned.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 232s 2s/step - accuracy: 0.5405 - auc: 0.5582 - loss: 0.8832 - precision: 0.5447 - recall: 0.6482 - val_accuracy: 0.5272 - val_auc: 0.8892 - val_loss: 0.7855 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 2/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7887 - auc: 0.8807 - loss: 0.5493 - precision: 0.7609 - recall: 0.8449
# Epoch 2: val_auc did not improve from 0.88918
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.7891 - auc: 0.8810 - loss: 0.5487 - precision: 0.7614 - recall: 0.8452 - val_accuracy: 0.5272 - val_auc: 0.5692 - val_loss: 1.0492 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 3/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8867 - auc: 0.9593 - loss: 0.4021 - precision: 0.8931 - recall: 0.8888
# Epoch 3: val_auc did not improve from 0.88918
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 200s 2s/step - accuracy: 0.8869 - auc: 0.9594 - loss: 0.4018 - precision: 0.8931 - recall: 0.8890 - val_accuracy: 0.5272 - val_auc: 0.6072 - val_loss: 0.8690 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00 - learning_rate: 1.0000e-05
# Epoch 4/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9361 - auc: 0.9853 - loss: 0.3080 - precision: 0.9461 - recall: 0.9314
# Epoch 4: val_auc did not improve from 0.88918
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9362 - auc: 0.9853 - loss: 0.3079 - precision: 0.9461 - recall: 0.9315 - val_accuracy: 0.5299 - val_auc: 0.5827 - val_loss: 0.9701 - val_precision: 1.0000 - val_recall: 0.0056 - learning_rate: 1.0000e-05
# Epoch 5/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9577 - auc: 0.9913 - loss: 0.2638 - precision: 0.9560 - recall: 0.9606
# Epoch 5: val_auc did not improve from 0.88918
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - accuracy: 0.9578 - auc: 0.9913 - loss: 0.2637 - precision: 0.9560 - recall: 0.9606 - val_accuracy: 0.5299 - val_auc: 0.3310 - val_loss: 0.9791 - val_precision: 0.7500 - val_recall: 0.0084 - learning_rate: 1.0000e-05
# Epoch 6/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9708 - auc: 0.9963 - loss: 0.2227 - precision: 0.9834 - recall: 0.9608
# Epoch 6: val_auc did not improve from 0.88918
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.9709 - auc: 0.9963 - loss: 0.2226 - precision: 0.9833 - recall: 0.9609 - val_accuracy: 0.6653 - val_auc: 0.6920 - val_loss: 0.7391 - val_precision: 0.8611 - val_recall: 0.3483 - learning_rate: 1.0000e-05
# Epoch 7/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9665 - auc: 0.9960 - loss: 0.2056 - precision: 0.9710 - recall: 0.9638
# Epoch 7: val_auc improved from 0.88918 to 0.96269, saving model to /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model_finetuned.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - accuracy: 0.9665 - auc: 0.9960 - loss: 0.2056 - precision: 0.9711 - recall: 0.9638 - val_accuracy: 0.8964 - val_auc: 0.9627 - val_loss: 0.4686 - val_precision: 0.8620 - val_recall: 0.9298 - learning_rate: 1.0000e-05
# Epoch 8/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9779 - auc: 0.9962 - loss: 0.1922 - precision: 0.9824 - recall: 0.9733
# Epoch 8: val_auc improved from 0.96269 to 0.99251, saving model to /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model_finetuned.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 218s 2s/step - accuracy: 0.9779 - auc: 0.9962 - loss: 0.1921 - precision: 0.9824 - recall: 0.9732 - val_accuracy: 0.8632 - val_auc: 0.9925 - val_loss: 0.3920 - val_precision: 0.7780 - val_recall: 0.9944 - learning_rate: 1.0000e-05
# Epoch 9/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9774 - auc: 0.9988 - loss: 0.1696 - precision: 0.9920 - recall: 0.9652
# Epoch 9: val_auc improved from 0.99251 to 0.99686, saving model to /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model_finetuned.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 183s 2s/step - accuracy: 0.9774 - auc: 0.9988 - loss: 0.1695 - precision: 0.9921 - recall: 0.9652 - val_accuracy: 0.9416 - val_auc: 0.9969 - val_loss: 0.2702 - val_precision: 0.8980 - val_recall: 0.9888 - learning_rate: 1.0000e-05
# Epoch 10/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9835 - auc: 0.9989 - loss: 0.1576 - precision: 0.9911 - recall: 0.9766
# Epoch 10: val_auc improved from 0.99686 to 0.99992, saving model to /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model_finetuned.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.9835 - auc: 0.9989 - loss: 0.1576 - precision: 0.9911 - recall: 0.9766 - val_accuracy: 0.9947 - val_auc: 0.9999 - val_loss: 0.1588 - val_precision: 0.9944 - val_recall: 0.9944 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 10.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✓ Best model loaded from /content/drive/MyDrive/wheat_models/EfficientNetB0/best_model_finetuned.h5
# ✓ EfficientNetB0 training completed successfully
#
# ==================================================
# Training ResNet50V2
# ==================================================
# ✗ ResNet50V2 training failed: Backbone ResNet50V2 not supported. Choose from: ['EfficientNetB0', 'MobileNetV2']
#
# ==================================================
# Training MobileNetV2
# ==================================================
# Class weights calculated: {0: np.float64(1.028125), 1: np.float64(0.9733727810650887)}
#
# PHASE 1: Training with frozen MobileNetV2 backbone...
# Epochs: 25
# Learning rate: 0.0001
# Epoch 1/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8167 - auc: 0.8843 - loss: 0.4846 - precision: 0.8445 - recall: 0.7682
# Epoch 1: val_auc improved from -inf to 0.99994, saving model to /content/drive/MyDrive/wheat_models/MobileNetV2/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 174s 2s/step - accuracy: 0.8179 - auc: 0.8854 - loss: 0.4825 - precision: 0.8456 - recall: 0.7697 - val_accuracy: 0.9973 - val_auc: 0.9999 - val_loss: 0.1892 - val_precision: 0.9972 - val_recall: 0.9972 - learning_rate: 1.0000e-04
# Epoch 2/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9780 - auc: 0.9962 - loss: 0.1720 - precision: 0.9702 - recall: 0.9869
# Epoch 2: val_auc improved from 0.99994 to 1.00000, saving model to /content/drive/MyDrive/wheat_models/MobileNetV2/best_model.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 146s 2s/step - accuracy: 0.9781 - auc: 0.9963 - loss: 0.1718 - precision: 0.9703 - recall: 0.9869 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_loss: 0.1274 - val_precision: 0.9972 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 3/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9847 - auc: 0.9995 - loss: 0.1323 - precision: 0.9786 - recall: 0.9925
# Epoch 3: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 204s 2s/step - accuracy: 0.9847 - auc: 0.9995 - loss: 0.1322 - precision: 0.9787 - recall: 0.9925 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1079 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 4/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9910 - auc: 0.9996 - loss: 0.1229 - precision: 0.9915 - recall: 0.9911
# Epoch 4: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9910 - auc: 0.9996 - loss: 0.1229 - precision: 0.9915 - recall: 0.9911 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0991 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 5/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9922 - auc: 0.9998 - loss: 0.1153 - precision: 0.9899 - recall: 0.9952
# Epoch 5: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 149s 2s/step - accuracy: 0.9923 - auc: 0.9998 - loss: 0.1153 - precision: 0.9899 - recall: 0.9952 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0961 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 6/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9947 - auc: 0.9998 - loss: 0.1111 - precision: 0.9958 - recall: 0.9944
# Epoch 6: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9947 - auc: 0.9998 - loss: 0.1111 - precision: 0.9958 - recall: 0.9944 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0947 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 7/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9915 - auc: 0.9998 - loss: 0.1145 - precision: 0.9932 - recall: 0.9903
# Epoch 7: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 216s 2s/step - accuracy: 0.9915 - auc: 0.9998 - loss: 0.1144 - precision: 0.9932 - recall: 0.9903 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0938 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 8/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9951 - auc: 0.9999 - loss: 0.1057 - precision: 0.9968 - recall: 0.9938
# Epoch 8: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9951 - auc: 0.9999 - loss: 0.1057 - precision: 0.9968 - recall: 0.9938 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0934 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 9/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9935 - auc: 0.9999 - loss: 0.1099 - precision: 0.9943 - recall: 0.9936
# Epoch 9: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 202s 2s/step - accuracy: 0.9936 - auc: 0.9999 - loss: 0.1099 - precision: 0.9943 - recall: 0.9937 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0928 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 10/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9960 - auc: 1.0000 - loss: 0.1028 - precision: 0.9952 - recall: 0.9970
# Epoch 10: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 188s 2s/step - accuracy: 0.9960 - auc: 1.0000 - loss: 0.1028 - precision: 0.9952 - recall: 0.9970 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0925 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 11/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9961 - auc: 1.0000 - loss: 0.1010 - precision: 0.9963 - recall: 0.9961
# Epoch 11: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 163s 2s/step - accuracy: 0.9962 - auc: 1.0000 - loss: 0.1010 - precision: 0.9963 - recall: 0.9961 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0921 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 12/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9966 - auc: 0.9995 - loss: 0.1087 - precision: 0.9969 - recall: 0.9964
# Epoch 12: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 150s 2s/step - accuracy: 0.9966 - auc: 0.9995 - loss: 0.1087 - precision: 0.9969 - recall: 0.9964 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0918 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 13/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9970 - auc: 1.0000 - loss: 0.0989 - precision: 0.9976 - recall: 0.9965
# Epoch 13: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.9970 - auc: 1.0000 - loss: 0.0989 - precision: 0.9976 - recall: 0.9966 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0915 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 14/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9984 - auc: 1.0000 - loss: 0.0991 - precision: 0.9995 - recall: 0.9975
# Epoch 14: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 201s 2s/step - accuracy: 0.9984 - auc: 1.0000 - loss: 0.0991 - precision: 0.9994 - recall: 0.9974 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0912 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 15/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9951 - auc: 0.9993 - loss: 0.1054 - precision: 0.9967 - recall: 0.9937
# Epoch 15: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9951 - auc: 0.9993 - loss: 0.1054 - precision: 0.9967 - recall: 0.9937 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0909 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 16/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9956 - auc: 0.9999 - loss: 0.1041 - precision: 0.9959 - recall: 0.9954
# Epoch 16: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 151s 2s/step - accuracy: 0.9956 - auc: 0.9999 - loss: 0.1040 - precision: 0.9959 - recall: 0.9955 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0907 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 17/25
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9991 - auc: 1.0000 - loss: 0.0947 - precision: 0.9988 - recall: 0.9993
# Epoch 17: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - accuracy: 0.9991 - auc: 1.0000 - loss: 0.0947 - precision: 0.9988 - recall: 0.9993 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.0903 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-04
# Epoch 17: early stopping
# Restoring model weights from the end of the best epoch: 2.
#
# PHASE 2: Fine-tuning with unfrozen backbone...
# Fine-tuning learning rate: 1e-05
# Epoch 1/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8923 - auc: 0.9598 - loss: 0.3479 - precision: 0.9203 - recall: 0.8704
# Epoch 1: val_auc improved from -inf to 1.00000, saving model to /content/drive/MyDrive/wheat_models/MobileNetV2/best_model_finetuned.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 217s 2s/step - accuracy: 0.8928 - auc: 0.9601 - loss: 0.3469 - precision: 0.9206 - recall: 0.8709 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1064 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 2/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9839 - auc: 0.9978 - loss: 0.1633 - precision: 0.9879 - recall: 0.9812
# Epoch 2: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - accuracy: 0.9839 - auc: 0.9978 - loss: 0.1632 - precision: 0.9878 - recall: 0.9812 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1040 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 3/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9844 - auc: 0.9990 - loss: 0.1425 - precision: 0.9830 - recall: 0.9865
# Epoch 3: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 199s 2s/step - accuracy: 0.9844 - auc: 0.9990 - loss: 0.1424 - precision: 0.9831 - recall: 0.9865 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_loss: 0.1029 - val_precision: 0.9972 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 4/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9881 - auc: 0.9989 - loss: 0.1370 - precision: 0.9883 - recall: 0.9885
# Epoch 4: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.9881 - auc: 0.9989 - loss: 0.1369 - precision: 0.9883 - recall: 0.9885 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_loss: 0.1046 - val_precision: 0.9972 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 5/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9952 - auc: 0.9999 - loss: 0.1168 - precision: 0.9945 - recall: 0.9963
# Epoch 5: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 205s 2s/step - accuracy: 0.9952 - auc: 0.9999 - loss: 0.1168 - precision: 0.9945 - recall: 0.9963 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_loss: 0.1023 - val_precision: 0.9972 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 6/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9935 - auc: 0.9997 - loss: 0.1184 - precision: 0.9940 - recall: 0.9931
# Epoch 6: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 168s 2s/step - accuracy: 0.9935 - auc: 0.9997 - loss: 0.1184 - precision: 0.9940 - recall: 0.9931 - val_accuracy: 0.9987 - val_auc: 1.0000 - val_loss: 0.1032 - val_precision: 0.9972 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 7/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9978 - auc: 0.9999 - loss: 0.1095 - precision: 0.9985 - recall: 0.9973
# Epoch 7: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 180s 2s/step - accuracy: 0.9978 - auc: 0.9999 - loss: 0.1095 - precision: 0.9984 - recall: 0.9973 - val_accuracy: 1.0000 - val_auc: 1.0000 - val_loss: 0.1016 - val_precision: 1.0000 - val_recall: 1.0000 - learning_rate: 1.0000e-05
# Epoch 8/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9965 - auc: 0.9999 - loss: 0.1092 - precision: 0.9953 - recall: 0.9978
# Epoch 8: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 192s 2s/step - accuracy: 0.9964 - auc: 0.9999 - loss: 0.1093 - precision: 0.9952 - recall: 0.9977 - val_accuracy: 0.9973 - val_auc: 1.0000 - val_loss: 0.1029 - val_precision: 1.0000 - val_recall: 0.9944 - learning_rate: 1.0000e-05
# Epoch 9/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9977 - auc: 1.0000 - loss: 0.1043 - precision: 0.9983 - recall: 0.9972
# Epoch 9: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 182s 2s/step - accuracy: 0.9977 - auc: 1.0000 - loss: 0.1043 - precision: 0.9983 - recall: 0.9972 - val_accuracy: 0.9973 - val_auc: 1.0000 - val_loss: 0.1031 - val_precision: 1.0000 - val_recall: 0.9944 - learning_rate: 1.0000e-05
# Epoch 10/10
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9941 - auc: 0.9999 - loss: 0.1099 - precision: 0.9939 - recall: 0.9946
# Epoch 10: val_auc did not improve from 1.00000
# 83/83 ━━━━━━━━━━━━━━━━━━━━ 168s 2s/step - accuracy: 0.9942 - auc: 0.9999 - loss: 0.1098 - precision: 0.9940 - recall: 0.9946 - val_accuracy: 0.9973 - val_auc: 1.0000 - val_loss: 0.1030 - val_precision: 1.0000 - val_recall: 0.9944 - learning_rate: 1.0000e-05
# Restoring model weights from the end of the best epoch: 1.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✓ Best model loaded from /content/drive/MyDrive/wheat_models/MobileNetV2/best_model_finetuned.h5
# ✓ MobileNetV2 training completed successfully
#
# ✓ Training completed for 2 models

# %% [markdown]
# ## 9. Comprehensive Model Evaluation

# %%
def plot_training_history(histories, save_path=None):
    """Plot comprehensive training history for all models"""

    fig, axes = plt.subplots(2, 2, figsize=(15, 10))
    fig.suptitle('Training History Comparison', fontsize=16)

    metrics = ['loss', 'accuracy', 'precision', 'recall']
    colors = plt.cm.Set1(np.linspace(0, 1, len(histories)))

    for i, (metric, ax) in enumerate(zip(metrics, axes.flatten())):
        for j, (model_name, history) in enumerate(histories.items()):
            if metric in history:
                epochs = range(1, len(history[metric]) + 1)
                ax.plot(epochs, history[metric],
                       color=colors[j], linestyle='-',
                       label=f'{model_name} (train)', alpha=0.8)

                val_metric = f'val_{metric}'
                if val_metric in history:
                    ax.plot(epochs, history[val_metric],
                           color=colors[j], linestyle='--',
                           label=f'{model_name} (val)', alpha=0.8)

        ax.set_title(metric.capitalize())
        ax.set_xlabel('Epoch')
        ax.set_ylabel(metric.capitalize())
        ax.legend(bbox_to_anchor=(1.05, 1), loc='upper left')
        ax.grid(True, alpha=0.3)

    plt.tight_layout()

    if save_path:
        plt.savefig(save_path, dpi=300, bbox_inches='tight')

    plt.show()

def evaluate_model_comprehensive(model, model_name, test_generator, config):
    """Comprehensive model evaluation with multiple metrics"""

    print(f"\nEvaluating {model_name}...")

    # Get predictions
    test_generator.reset()
    predictions = model.predict(test_generator, verbose=1)
    predicted_classes = (predictions > 0.5).astype(int).flatten()

    # Get true labels
    true_labels = test_generator.classes

    # Calculate metrics
    test_loss, test_accuracy, test_precision, test_recall, test_auc = model.evaluate(
        test_generator, verbose=0
    )

    # Additional metrics
    f1 = f1_score(true_labels, predicted_classes)
    roc_auc = roc_auc_score(true_labels, predictions)

    # Classification report
    class_names = list(test_generator.class_indices.keys())
    class_report = classification_report(
        true_labels, predicted_classes,
        target_names=class_names,
        output_dict=True
    )

    results = {
        'model_name': model_name,
        'test_loss': test_loss,
        'test_accuracy': test_accuracy,
        'test_precision': test_precision,
        'test_recall': test_recall,
        'test_auc': test_auc,
        'f1_score': f1,
        'roc_auc': roc_auc,
        'classification_report': class_report,
        'predictions': predictions.flatten(),
        'predicted_classes': predicted_classes,
        'true_labels': true_labels
    }

    # Print results
    print(f"Test Results for {model_name}:")
    print(f"  Accuracy: {test_accuracy:.4f}")
    print(f"  Precision: {test_precision:.4f}")
    print(f"  Recall: {test_recall:.4f}")
    print(f"  F1-Score: {f1:.4f}")
    print(f"  ROC AUC: {roc_auc:.4f}")

    return results

def plot_evaluation_results(results_dict, config):
    """Plot comprehensive evaluation results"""

    n_models = len(results_dict)
    fig, axes = plt.subplots(2, 2, figsize=(16, 12))
    fig.suptitle('Model Evaluation Results', fontsize=16)

    # Metrics comparison
    metrics = ['test_accuracy', 'test_precision', 'test_recall', 'f1_score']
    model_names = list(results_dict.keys())

    for i, (metric, ax) in enumerate(zip(metrics, axes.flatten())):
        values = [results_dict[name][metric] for name in model_names]

        bars = ax.bar(model_names, values, alpha=0.8,
                     color=plt.cm.Set3(np.linspace(0, 1, n_models)))

        # Add value labels on bars
        for bar, value in zip(bars, values):
            height = bar.get_height()
            ax.text(bar.get_x() + bar.get_width()/2., height + 0.01,
                   f'{value:.3f}', ha='center', va='bottom')

        ax.set_title(metric.replace('_', ' ').title())
        ax.set_ylim(0, 1.1)
        ax.tick_params(axis='x', rotation=45)
        ax.grid(True, alpha=0.3)

    plt.tight_layout()

    # Save plot
    save_path = config['results_dir'] / 'model_comparison.png'
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()

    print(f"✓ Evaluation plots saved to {save_path}")

def plot_confusion_matrices(results_dict, config):
    """Plot confusion matrices for all models"""

    n_models = len(results_dict)
    cols = min(3, n_models)
    rows = (n_models + cols - 1) // cols

    fig, axes = plt.subplots(rows, cols, figsize=(5*cols, 4*rows))
    if n_models == 1:
        axes = [axes]
    elif rows == 1:
        axes = axes.flatten()
    else:
        axes = axes.flatten()

    class_names = ['Not Ready', 'Ready']

    for i, (model_name, results) in enumerate(results_dict.items()):
        cm = confusion_matrix(results['true_labels'], results['predicted_classes'])

        sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                   xticklabels=class_names, yticklabels=class_names,
                   ax=axes[i])

        axes[i].set_title(f'{model_name} Confusion Matrix')
        axes[i].set_xlabel('Predicted')
        axes[i].set_ylabel('Actual')

    # Hide unused subplots
    for i in range(n_models, len(axes)):
        axes[i].set_visible(False)

    plt.tight_layout()

    # Save plot
    save_path = config['results_dir'] / 'confusion_matrices.png'
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()

    print(f"✓ Confusion matrices saved to {save_path}")

def plot_roc_curves(results_dict, config):
    """Plot ROC curves for all models"""

    plt.figure(figsize=(10, 8))
    colors = plt.cm.Set1(np.linspace(0, 1, len(results_dict)))

    for i, (model_name, results) in enumerate(results_dict.items()):
        fpr, tpr, _ = roc_curve(results['true_labels'], results['predictions'])
        roc_auc = auc(fpr, tpr)

        plt.plot(fpr, tpr, color=colors[i], lw=2,
                label=f'{model_name} (AUC = {roc_auc:.3f})')

    plt.plot([0, 1], [0, 1], 'k--', lw=2, label='Random Classifier')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curves Comparison')
    plt.legend(loc="lower right")
    plt.grid(True, alpha=0.3)

    # Save plot
    save_path = config['results_dir'] / 'roc_curves.png'
    plt.savefig(save_path, dpi=300, bbox_inches='tight')
    plt.show()

    print(f"✓ ROC curves saved to {save_path}")

# %%
# Plot training histories
if training_histories:
    print("Plotting training histories...")
    history_plot_path = CONFIG['results_dir'] / 'training_history.png'
    plot_training_history(training_histories, history_plot_path)

# Evaluate all trained models
evaluation_results = {}

for model_name in trained_models.keys():
    # Load best model
    model_path = CONFIG['models_dir'] / model_name / 'best_model_finetuned.h5'
    if model_path.exists():
        try:
            model = keras.models.load_model(str(model_path))
            results = evaluate_model_comprehensive(
                model, model_name, data_generators['test'], CONFIG
            )
            evaluation_results[model_name] = results

            # Save individual results
            results_file = CONFIG['results_dir'] / f'{model_name}_results.json'
            # Convert numpy arrays to lists for JSON serialization
            json_results = results.copy()
            json_results['predictions'] = results['predictions'].tolist()
            json_results['predicted_classes'] = results['predicted_classes'].tolist()
            json_results['true_labels'] = results['true_labels'].tolist()

            with open(results_file, 'w') as f:
                json.dump(json_results, f, indent=2, default=str)

        except Exception as e:
            print(f"✗ Error evaluating {model_name}: {e}")

# Generate comparison plots
if evaluation_results:
    print("\nGenerating evaluation plots...")
    plot_evaluation_results(evaluation_results, CONFIG)
    plot_confusion_matrices(evaluation_results, CONFIG)
    plot_roc_curves(evaluation_results, CONFIG)

    # Create summary table
    summary_data = []
    for model_name, results in evaluation_results.items():
        summary_data.append({
            'Model': model_name,
            'Accuracy': f"{results['test_accuracy']:.4f}",
            'Precision': f"{results['test_precision']:.4f}",
            'Recall': f"{results['test_recall']:.4f}",
            'F1-Score': f"{results['f1_score']:.4f}",
            'ROC AUC': f"{results['roc_auc']:.4f}"
        })

    summary_df = pd.DataFrame(summary_data)

    print("\n" + "="*70)
    print("FINAL MODEL COMPARISON SUMMARY")
    print("="*70)
    print(summary_df.to_string(index=False))
# Out:
# Plotting training histories...
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Evaluating EfficientNetB0...
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 30s 2s/step
# ✗ Error evaluating EfficientNetB0: Input contains NaN.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Evaluating MobileNetV2...
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 14s 1s/step
# Test Results for MobileNetV2:
#   Accuracy: 1.0000
#   Precision: 1.0000
#   Recall: 1.0000
#   F1-Score: 1.0000
#   ROC AUC: 1.0000
#
# Generating evaluation plots...
# ✓ Evaluation plots saved to /content/drive/MyDrive/wheat_results/model_comparison.png
# ✓ Confusion matrices saved to /content/drive/MyDrive/wheat_results/confusion_matrices.png
# ✓ ROC curves saved to /content/drive/MyDrive/wheat_results/roc_curves.png
#
# ======================================================================
# FINAL MODEL COMPARISON SUMMARY
# ======================================================================
#       Model Accuracy Precision Recall F1-Score ROC AUC
# MobileNetV2   1.0000    1.0000 1.0000   1.0000  1.0000
